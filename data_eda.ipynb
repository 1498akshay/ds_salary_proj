# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option("display.max_columns",None)
df = pd.read_csv("salary_data_cleaned.csv")
df
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# 5                                       Data Scientist
# 6                                       Data Scientist
# 7                                       Data Scientist
# 8                                   Research Scientist
# 9                                       Data Scientist
# 10                                      Data Scientist
# 11                                      Data Scientist
# 12                   Staff Data Scientist - Technology
# 13                                        Data Analyst
# 14                                      Data Scientist
# 15                                     Data Engineer I
# ...

# %%
def title_simplifier(title):
    if "data scientist" in title.lower():
        return "data scientist"
    elif "data engineer" in title.lower():
        return "data engineer"
    elif "machine learning" in title.lower():
        return "mle"
    elif "analyst" in title.lower():
        return "analyst"
    elif "machine learning" in title.lower():
        return "mle"
    elif "manager" in title.lower():
        return "manager"
    elif "director" in title.lower():
        return "director"
    else:
        return "na"

def seniority(title):
    if "sr" in title.lower() or "senior" in title.lower() or "lead" in title.lower()or "principal" in title.lower():
        return "senior"
    elif "jr" in title.lower() or "jr." in title.lower():
        return "junior"
    else:
        return "na"

# %%
df["job_simplified"]= df["Job Title"].apply(title_simplifier)
df.job_simplified.value_counts()
# Out:
# data scientist    279
# na                184
# data engineer     119
# analyst           102
# manager            22
# mle                22
# director           14
# Name: job_simplified, dtype: int64

# %%
df["seniority"]= df["Job Title"].apply(lambda x : seniority(x))
df.seniority.value_counts()
# Out:
# na        520
# senior    220
# junior      2
# Name: seniority, dtype: int64

# %%
#fix los angeles
df.job_state.value_counts()
df["job_state"] = df.job_state.apply(lambda x: x.strip() if x.strip() != "Los Angeles" else "CA")
df.job_state.value_counts()
# Out:
# CA    152
# MA    103
# NY     72
# VA     41
# IL     40
# MD     35
# PA     33
# TX     28
# NC     21
# WA     21
# NJ     17
# FL     16
# OH     14
# TN     13
# DC     11
# CO     11
# WI     10
# UT     10
# IN     10
# AZ      9
# MO      9
# AL      8
# GA      6
# DE      6
# KY      6
# MI      6
# CT      5
# IA      5
# LA      4
# OR      4
# NE      4
# NM      3
# KS      3
# ID      2
# MN      2
# RI      1
# SC      1
# Name: job_state, dtype: int64

# %%
# job discription ength
df["desc_len"]= df["Job Description"].apply(lambda x: len(x))
df["desc_len"]
# Out:
# 0       2555
# 1       4828
# 2       3495
# 3       3926
# 4       2748
# 5       3783
# 6       1808
# 7       3847
# 8       1561
# 9       4609
# 10      2789
# 11      3522
# 12      3980
# 13      4942
# 14      3799
# 15      1902
# 16      3676
# 17      4201
# 18      3549
# 19      4434
# 20      2944
# 21      6967
# 22      6472
# 23      2951
# 24      3806
# 25      3728
# 26      4452
# 27      4984
# 28      5057
# 29      3495
# 30      3926
# 31      3376
# 32      5126
# 33      2378
# 34      2187
# 35      1753
# 36      5044
# 37      3736
# 38      3602
# 39      1758
# 40      3079
# 41      2042
# 42      3872
# 43      3558
# 44      9165
# 45      3239
# 46      7325
# 47      3438
# 48      2730
# 49      2769
# 50      2953
# 51      4277
# 52      1649
# 53      4772
# 54      4495
# 55      3590
# 56      4244
# 57      5065
# 58      1808
# 59      3783
# 60      4852
# 61      1409
# 62      2962
# 63      4991
# 64      2527
# 65      1963
# ...

# %%
#competitors
df["num_comp"] = df["Competitors"].apply(lambda x: len(x.split(",")) if x != -1 else 0 )
df["num_comp"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      3
# 4      3
# 5      3
# 6      1
# 7      1
# 8      1
# 9      2
# 10     1
# 11     1
# 12     3
# 13     1
# 14     3
# 15     1
# 16     3
# 17     1
# 18     1
# 19     1
# 20     3
# 21     1
# 22     1
# 23     1
# 24     3
# 25     1
# 26     1
# 27     1
# 28     1
# 29     1
# 30     3
# 31     1
# 32     1
# 33     1
# 34     3
# 35     1
# 36     1
# 37     1
# 38     1
# 39     1
# 40     3
# 41     1
# 42     1
# 43     3
# 44     3
# 45     1
# 46     3
# 47     1
# 48     3
# 49     3
# 50     1
# 51     3
# 52     1
# 53     3
# 54     1
# 55     1
# 56     3
# 57     2
# 58     1
# 59     3
# 60     1
# 61     1
# 62     1
# 63     3
# 64     3
# 65     1
# 66     1
# 67     4
# 68     1
# 69     1
# 70     1
# 71     1
# 72     1
# 73     3
# 74     3
# 75     1
# 76     1
# 77     1
# 78     1
# 79     3
# 80     1
# 81     1
# 82     3
# 83     3
# 84     1
# 85     1
# 86     3
# 87     1
# 88     1
# 89     1
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'job_state', 'same_state', 'age', 'python_yn',
#        'rstudio_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'job_simplified',
#        'seniority', 'desc_len', 'num_comp'],
#       dtype='object')

# %%
# hourly wages to annual
df["min_salary"] = df.apply(lambda x: x.min_salary *2 if x.hourly == 1 else x.min_salary, axis =1)
df["max_salary"] = df.apply(lambda x: x.max_salary *2 if x.hourly == 1 else x.max_salary, axis =1)
df[df.hourly ==1][["hourly","min_salary","max_salary"]]
# Out:
#      hourly  min_salary  max_salary
# 165       1          34          48
# 177       1          42          68
# 197       1          36          50
# 202       1          42          68
# 210       1          30          50
# 246       1          34          48
# 271       1          42          68
# 337       1          36          50
# 345       1          48          78
# 357       1          42          68
# 363       1          50          56
# 408       1          42          58
# 409       1          20          34
# 492       1          36          50
# 509       1          48          78
# 533       1          42          68
# 542       1          50          56
# 617       1          42          58
# 618       1          20          34
# 645       1          54          94
# 666       1          36          50
# 682       1          48          78
# 711       1          42          68
# 724       1          50          56

# %%
df['company_text'] = df.company_text.apply(lambda x : x.replace("\r\n",""))
df['company_text']
# Out:
# 0                                      Tecolote Research
# 1                  University of Maryland Medical System
# 2                                                KnowBe4
# 3                                                   PNNL
# 4                                     Affinity Solutions
# 5                                               CyrusOne
# 6                                     ClearOne Advantage
# 7                                             Logic20/20
# 8                              Rochester Regional Health
# 9                                               <intent>
# 10                                                  Wish
# 11                                               ManTech
# 12                                               Walmart
# 13                                                Yesler
# 14                                Takeda Pharmaceuticals
# 15                                               Audible
# ...

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  employer provided  min_salary  \
# count  742.000000   742.000000  742.000000         742.000000  742.000000
# mean     3.618868  1837.154987    0.032345           0.022911   74.719677
# std      0.801210   497.183763    0.177034           0.149721   30.980593
# min     -1.000000    -1.000000    0.000000           0.000000   15.000000
# 25%      3.300000  1939.000000    0.000000           0.000000   52.000000
# 50%      3.700000  1988.000000    0.000000           0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000           0.000000   91.000000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        max_salary  avg_salary  same_state         age   python_yn  rstudio_yn  \
# count  742.000000  742.000000  742.000000  742.000000  742.000000  742.000000
# mean   128.149596  100.626011    0.557951   49.389488    0.528302    0.002695
# ...

# %%
df.Rating.hist()
# Out:
# <AxesSubplot:>

# %%
df.avg_salary.hist()
# Out:
# <AxesSubplot:>

# %%
df.age.hist()
# Out:
# <AxesSubplot:>

# %%
df.desc_len.hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = ["age","avg_salary","Rating"])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = "Rating")
# Out:
# <AxesSubplot:>

# %%
df[["age","avg_salary","Rating","desc_len","num_comp"]].corr()
# Out:
#                  age  avg_salary    Rating  desc_len  num_comp
# age         1.000000    0.019410  0.026164  0.165891  0.139800
# avg_salary  0.019410    1.000000  0.013492  0.078093  0.088790
# Rating      0.026164    0.013492  1.000000 -0.012631  0.021395
# desc_len    0.165891    0.078093 -0.012631  1.000000  0.109551
# num_comp    0.139800    0.088790  0.021395  0.109551  1.000000

# %%
cmap= sns.diverging_palette(220,10,as_cmap=True)
sns.heatmap(df[["age","avg_salary","Rating","desc_len","num_comp"]].corr(),vmax=.3,center=0,cmap=cmap,square= True, linewidths= .5,cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'job_state', 'same_state', 'age', 'python_yn',
#        'rstudio_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'job_simplified',
#        'seniority', 'desc_len', 'num_comp'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue','company_text','job_state','same_state','python_yn',
       'rstudio_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'job_simplified', 'seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total %d" % (i, len(cat_num)))
    chart = sns.barplot(x= cat_num.index, y = cat_num)
    chart.set_xticklabels(chart.get_xticklabels(),rotation = 90)
    plt.show()
# Out:
# graph for Location: total 200
# graph for Headquarters: total 198
# graph for Size: total 9
# graph for Type of ownership: total 11
# graph for Industry: total 60
# graph for Sector: total 25
# graph for Revenue: total 14
# graph for company_text: total 343
# graph for job_state: total 37
# graph for same_state: total 2
# graph for python_yn: total 2
# graph for rstudio_yn: total 2
# graph for spark_yn: total 2
# graph for aws_yn: total 2
# graph for excel_yn: total 2
# graph for job_simplified: total 7
# graph for seniority: total 3

# %%
for i in df_cat[["Location","Headquarters","company_text"]].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total %d" % (i, len(cat_num)))
    chart = sns.barplot(x= cat_num.index, y = cat_num)
    chart.set_xticklabels(chart.get_xticklabels(),rotation = 90)
    plt.show()
# Out:
# graph for Location: total 20
# graph for Headquarters: total 20
# graph for company_text: total 20

# %%
pd.pivot_table(df,index = ["job_simplified","seniority"], values= "avg_salary")
# Out:
#                           avg_salary
# job_simplified seniority
# analyst        junior      56.500000
#                na          61.155405
#                senior      79.092593
# data engineer  na          96.701220
#                senior     124.689189
# data scientist junior     106.500000
#                na         107.043011
#                senior     138.956522
# director       na         168.607143
# manager        na          84.022727
# mle            na         119.133333
#                senior     142.071429
# na             na          73.988189
#                senior     109.061404

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'job_state', 'same_state', 'age', 'python_yn',
#        'rstudio_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'job_simplified',
#        'seniority', 'desc_len', 'num_comp'],
#       dtype='object')

# %%
pd.set_option("display.max_rows",None)
pd.pivot_table(df,index = ["job_state","job_simplified"], values= "avg_salary",aggfunc = "count" ).sort_values("job_state", ascending = False)
# Out:
#                           avg_salary
# job_state job_simplified
# WI        na                       4
#           data scientist           3
#           analyst                  3
# WA        na                       1
#           data scientist          17
#           analyst                  3
# VA        na                       5
#           mle                      2
#           data scientist          18
#           data engineer           10
#           analyst                  6
# UT        data engineer            3
#           analyst                  4
#           data scientist           3
# TX        na                       7
#           data scientist          13
#           data engineer            8
# TN        data scientist           1
#           data engineer           10
#           analyst                  2
# SC        na                       1
# RI        analyst                  1
# PA        manager                  3
# ...

# %%
df[["job_state","job_simplified"]].value_counts()
# Out:
# job_state  job_simplified
# CA         data scientist    68
# MA         na                46
# NY         data scientist    40
# MA         data scientist    30
# CA         na                27
#            data engineer     25
# VA         data scientist    18
# CA         analyst           18
# WA         data scientist    17
# MD         na                16
# IL         data scientist    15
# NY         analyst           14
# MD         data scientist    13
# TX         data scientist    13
# NC         na                12
# MA         data engineer     12
# NY         na                12
# VA         data engineer     10
# TN         data engineer     10
# CA         manager            9
# IL         data engineer      8
# TX         data engineer      8
# PA         na                 8
#            analyst            8
#            mle                7
# TX         na                 7
# FL         data scientist     7
# OH         data scientist     7
# ...

# %%
pd.pivot_table(df[df.job_simplified== "data scientist"],index = ["job_state","job_simplified"], values= "avg_salary").sort_values("avg_salary", ascending = False)
# Out:
#                           avg_salary
# job_state job_simplified
# DC        data scientist  149.000000
# CA        data scientist  142.522059
# UT        data scientist  140.500000
# MO        data scientist  127.666667
# IL        data scientist  117.233333
# NC        data scientist  117.000000
# NY        data scientist  115.250000
# MA        data scientist  113.750000
# WI        data scientist  113.500000
# PA        data scientist  113.333333
# MD        data scientist  109.115385
# CO        data scientist  108.666667
# VA        data scientist  108.416667
# NJ        data scientist  106.875000
# MI        data scientist  106.625000
# OH        data scientist  105.285714
# TX        data scientist  100.730769
# WA        data scientist   99.764706
# OR        data scientist   98.500000
# FL        data scientist   97.357143
# TN        data scientist   96.000000
# IN        data scientist   84.500000
# KY        data scientist   84.000000
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'job_state', 'same_state', 'age', 'python_yn',
#        'rstudio_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'job_simplified',
#        'seniority', 'desc_len', 'num_comp'],
#       dtype='object')

# %%
# rating,industry , sector,revenue,number of comp, ourly, employer provided, python,r,spark,aws,excel,desc_len,num_comp, type of owership

# %%
df_pivots =df[["Rating","Industry" , "Sector","Revenue",'num_comp', "hourly", "employer provided", "python_yn","rstudio_yn","spark_yn","aws_yn","excel_yn", "Type of ownership","avg_salary"]]
df_pivots
# Out:
#      Rating                                  Industry  \
# 0       3.8                       Aerospace & Defense
# 1       3.4          Health Care Services & Hospitals
# 2       4.8                         Security Services
# 3       3.8                                    Energy
# 4       2.9                   Advertising & Marketing
# 5       3.4                               Real Estate
# 6       4.1                     Banks & Credit Unions
# 7       3.8                                Consulting
# 8       3.3          Health Care Services & Hospitals
# 9       4.6                                  Internet
# 10      3.5                       Other Retail Stores
# 11      4.1                    Research & Development
# 12      3.2       Department, Clothing, & Shoe Stores
# 13      4.1                   Advertising & Marketing
# 14      3.7                 Biotech & Pharmaceuticals
# 15      3.6  Motion Picture Production & Distribution
# ...

# %%
for i in df_pivots.columns:
    if i != "avg_salary":
        print(i)
        print(pd.pivot_table(df_pivots, index = i, values="avg_salary").sort_values("avg_salary",ascending=False))
    else:
        pass
# Out:
# Rating
#         avg_salary
# Rating
# -1.0    136.181818
#  5.0    134.700000
#  2.5    120.000000
#  4.5    117.714286
#  4.1    116.368421
#  3.9    113.071429
#  2.6    109.083333
#  4.4    108.606061
#  3.2    105.500000
#  4.0    105.340426
#  3.5    104.897959
#  3.7    104.131148
#  4.7    103.983871
#  4.3    102.468750
#  3.3    101.858974
#  4.2    100.442308
#  2.2     97.750000
#  4.6     97.250000
#  3.8     96.811475
#  2.1     95.900000
#  3.4     93.011364
#  1.9     87.500000
#  3.1     86.580000
#  3.0     85.588235
#  3.6     85.467391
#  2.8     83.928571
#  2.7     83.250000
#  2.3     81.500000
#  2.9     81.138889
#  4.8     80.277778
#  2.4     60.214286
# Industry
#                                           avg_salary
# Industry
# Other Retail Stores                       163.500000
# Motion Picture Production & Distribution  146.000000
# Financial Analytics & Research            145.125000
# Health, Beauty, & Fitness                 139.500000
# ...

# %%
pd.pivot_table(df_pivots, index = "Revenue",  columns ="python_yn", values ="avg_salary", aggfunc="count")
# Out:
# python_yn                            0      1
# Revenue
# $1 to $2 billion (USD)            16.0   44.0
# $1 to $5 million (USD)             1.0    7.0
# $10 to $25 million (USD)          16.0   16.0
# $10+ billion (USD)                66.0   58.0
# $100 to $500 million (USD)        47.0   44.0
# $2 to $5 billion (USD)            17.0   22.0
# $25 to $50 million (USD)          24.0   16.0
# $5 to $10 billion (USD)            9.0   10.0
# $5 to $10 million (USD)            9.0    9.0
# $50 to $100 million (USD)         21.0   25.0
# $500 million to $1 billion (USD)  29.0   28.0
# -1                                 1.0    NaN
# Less than $1 million (USD)         1.0    3.0
# Unknown / Non-Applicable          93.0  110.0
